# %% [markdown]
# # Lab 2 – Strings and Input

# %% [markdown]
# ## Problem 1
# Create two variables called `color` and `thing`. Assign them any values you like. Then combine them into one phrase using an f-string and print the result.
# Example: `"purple balloon"`

# %%
# code here
color = "blue"
thing = "book"
print(f"{color} {thing}")
# Out:
# blue book

# %% [markdown]
# ## Problem 2
# Ask the user for their favorite animal using `input()`. Store it in a variable. Then, using an f-string, print:
# `You like <animal>s!`

# %%
# code here
animal = input("Enter your favorite animal: ")
print(f"You like {animal}s!")
# Out:
# You like cats!

# %% [markdown]
# ## Problem 3
#
# Ask the user for the radius of a circle (decimal allowed). Calculate and print the area rounded to **2 decimal places**.
#
# The formula is:  $Area = \pi \times r^2$
#
# consider pi = 3.14159
#
# `Enter the radius of the circle: 5`
#
# `The area of the circle is 78.54`

# %%
import math

r = input("Enter radius: ")
Area = math.pi * float(r)**2
print(f"{Area:.2f}")
# Out:
# 78.54

# %% [markdown]
# ## Problem 4
# Ask the user to type two whole numbers. Store them in variables `a` and `b`. Then print out a sentence showing the **division** using an f-string.
#
# Example:
# `10 / 10 = 1.0`

# %%
# code here
a = input("Enter value A: ")
b = input("Enter value B: ")
quotient = float(a) / float(b)
print(f"{a} / {b} = {quotient}")
# Out:
# 1 / 1 = 1.0

# %% [markdown]
# ## Problem 5
# Ask the user for the bill amount. Add a **10% tip** and print the total rounded to **2 decimal places**.
#
# Example:
# If the bill is `50`, the total should be `55.00`.

# %%
# code here
subtotal = input("Enter bill amount: ")
total = float(subtotal) * 1.1
print(f"If the bill is {subtotal}, the total should be {total:.2f}")
# Out:
# If the bill is 50, the total should be 55.00

# %% [markdown]
# ## Problem 6
# Write a short code snippet that takes in the **name of a movie** and its **ticket price as a decimal number**. Then you should output how much it would cost to buy 2, 3, 5, and 8 tickets for that movie. The amounts should be formatted as currency, with commas and two decimals. You must use **f-string**. To format a number with commas using f-strings,
#
# Example output for a movie *Demon Slayer* that costs 9.75 per ticket would look like:
#
# `A 'Demon Slayer' ticket costs $9.75.`<br/>
# &nbsp;&nbsp;&nbsp;&nbsp;`2   tickets cost $19.50`<br/>
# &nbsp;&nbsp;&nbsp;&nbsp;`3   tickets cost $29.25`<br/>
# &nbsp;&nbsp;&nbsp;&nbsp;`5   tickets cost $48.75`<br/>
# &nbsp;&nbsp;&nbsp;&nbsp;`8   tickets cost $78.00`<br/>
#
# *Note that it is easier to finish one of the cost lines first, then copy/paste and modify for the rest.*

# %%
# code here
name = input("Enter name of movie: ")
cost = float(input("Enter cost of 1 ticket: "))
print(f"A '{name}' ticket costs ${cost:.2f}")
print(f"2 tickets cost ${2 * cost:.2f}")
print(f"3 tickets cost ${3 * cost:.2f}")
print(f"5 tickets cost ${5 * cost:.2f}")
print(f"8 tickets cost ${8 * cost:.2f}")
# Out:
# A 'Demon Slayer' ticket costs $9.75
# 2 tickets cost $19.50
# 3 tickets cost $29.25
# 5 tickets cost $48.75
# 8 tickets cost $78.00

# %% [markdown]
# ## Problem 7
# Using string slicing, print only "Game" from the  variable below. `text = "Game Over!"`

# %%
text = "Game Over!"
print(text[:4])
# Out:
# Game

# %% [markdown]
# ## Problem 8
# Use string slicing to print "desserts" backwards from the variable below `word = "stressed"`.

# %%
word = "stressed"
print(word[::-1])
# Out:
# desserts

# %% [markdown]
# ## Problem 9
# The variable below stores  `text = "Kansas State University"`.  Use string slicing to print the `State` from the middle

# %%
text = "Kansas State University"
print(text[7:13])
# Out:
# State

# %% [markdown]
# ## Problem 10
# Use string slicing to extract and print out the secret from the variable below. You are not allowed to change the value of the `hidden_secret` variable. This can be done using a single slice. *Hint: change the step for your slice.*

# %%
hidden_secret = "xxxOxxxpxxxexxxnxxxAxxxI"
print(hidden_secret[3::4])
# Out:
# OpenAI
