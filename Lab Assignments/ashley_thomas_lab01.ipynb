# %% [markdown]
# Introduce yourself with a string like `Hello, my name is Safia`.  Do not use the print statement.

# %%
"Hello, my name is Tommy"
# Out:
# 'Hello, my name is Tommy'

# %% [markdown]
# Take the previous string you created and store it into a well-named variable. Then, output it using the _print_ statement.

# %%
myself = "Hello, my name is Tommy."
print(myself)
# Out:
# Hello, my name is Tommy.

# %% [markdown]
# Add a second sentence to string you used above and output it here.  The second sentence should appear on a new line.

# %%
myself += "\nI am a freshmen studying computer science."
print(myself)
# Out:
# Hello, my name is Tommy.
# I am a freshmen studying computer science.

# %% [markdown]
# Add a third sentence to the string and output it here.  The third sentence should be tabbed in two spaces and appear on a new line.  The second sentence should be tabbed in one space and also appear on a new line.

# %%
myself += " \n \tI am in a Fraternity."
print(myself)
# Out:
# Hello, my name is Tommy.
# I am a freshmen studying computer science.
#  	I am in a Fraternity.

# %% [markdown]
# Fix the code snippets below so they output correctly

# %%
print("Python is pretty fun.  I don't think it will take me long to master it")
# Out:
# Python is pretty fun.  I don't think it will take me long to master it

# %%
print('Can you believe that \\t adds a tab character in a string in Python?')
# Out:
# Can you believe that \t adds a tab character in a string in Python?

# %%
print("Some folks say putting quotes arround a word like \"this\" is pretty easy, but I think its hard")
# Out:
# Some folks say putting quotes arround a word like "this" is pretty easy, but I think its hard

# %% [markdown]
# What is the average number of hours of classes you take compared to the rest of the time you have in a week? (class hours divided by number of hours in a week) Store this number into a variable and output it.

# %%
class2week_hours = 13 / 168
print(class2week_hours)
# Out:
# 0.07738095238095238

# %% [markdown]
# Take the calculation above (the variable) and convert it into a percentage. This result should be stored into a variable and outputed.

# %%
class2week_hours_percentage = class2week_hours * 100
print(class2week_hours_percentage)
# Out:
# 7.738095238095238%

# %% [markdown]
# What is the remainder of taking 4128071 divded by 46? This result should be stored into a variable and outputed.

# %%
remainder = 4128071 % 46
print(remainder)
# Out:
# 31

# %% [markdown]
# What is the cosine of 4? This result should be stored into a variable and outputed.

# %%
import math
result = math.cos(math.radians(4))
print(result)
# Out:
# 0.9975640502598242

# %% [markdown]
# How can we calculate the average of three different variables? Show an example.

# %%
a = 1
b = 2
c = 3

avg = (a + b + c) / 3

print(avg)
# Out:
# 2.0
